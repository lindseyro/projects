# %% [markdown]
# # Project 1: SAT & ACT Analysis

# %% [markdown]
# The first markdown cell in a notebook is a great place to provide an overview of your entire project. You will likely want to at least state your
#
# ## Problem Statement

# %% [markdown]
# as well as an

# %% [markdown]
# ## Executive Summary
#
# If you want to, it's great to use relative links to direct your audience to various sections of your notebook. **HERE'S A DEMONSTRATION WITH THE CURRENT SECTION HEADERS**:
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# **If you combine your problem statement, executive summary, data dictionary, and conclusions/recommendations, you have a good README.md file.**
#
# Don't forget to cite your data sources!

# %% [markdown]
# *All libraries used should be added here*

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix, andrews_curves, parallel_coordinates
import seaborn as sns

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %% [markdown]
# #### 1. Read In SAT & ACT  Data

# %%
sat_17 = pd.read_csv('../data/sat_2017.csv')

# %%
act_17 = pd.read_csv('../data/act_2017.csv')

# %%
# actual data from act website: https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf

act_17
# Out:
#                    State Participation  English  Math  Reading  Science  \
# 0               National           60%     20.3  20.7     21.4     21.0
# 1                Alabama          100%     18.9  18.4     19.7     19.4
# 2                 Alaska           65%     18.7  19.8     20.4     19.9
# 3                Arizona           62%     18.6  19.8     20.1     19.8
# 4               Arkansas          100%     18.9  19.0     19.7     19.5
# 5             California           31%     22.5  22.7     23.1     22.2
# 6               Colorado          100%     20.1  20.3     21.2     20.9
# 7            Connecticut           31%     25.5  24.6     25.6     24.6
# 8               Delaware           18%     24.1  23.4     24.8     23.6
# 9   District of Columbia           32%     24.4  23.5     24.9     23.5
# 10               Florida           73%     19.0  19.4     21.0     19.4
# 11               Georgia           55%     21.0  20.9     22.0     21.3
# ...

# %%
sat_17
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 0                Alabama            5%                                 593
# 1                 Alaska           38%                                 547
# 2                Arizona           30%                                 563
# 3               Arkansas            3%                                 614
# 4             California           53%                                 531
# 5               Colorado           11%                                 606
# 6            Connecticut          100%                                 530
# 7               Delaware          100%                                 503
# 8   District of Columbia          100%                                 482
# 9                Florida           83%                                 520
# 10               Georgia           61%                                 535
# ...

# %%
'Total Reading is {}. Total Math is {}. Total Total is {}'.format(sum(sat_17['Evidence-Based Reading and Writing']), sum(sat_17['Math']), sum(sat_17['Total']))
# Out:
# 'Total Reading is 29025. Total Math is 27929. Total Total is 57431'

# %%
# Maryland Difference
sat_17['Total'][20] - sat_17['Evidence-Based Reading and Writing'][20]
# Out:
# 524

# %%
sum(sat_17['Evidence-Based Reading and Writing']) + sum(sat_17['Math']) - 52 + 524
# Out:
# 57426

# %%
sat_17.sort_values('Math').head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           69%                                 536
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005

# %%
sat_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 2. Preview and inspect the data

# %%
sorted_sat_17 = sat_17.sort_values('Participation')

plt.figure(figsize = (15,10))
plt.barh(sorted_sat_17['State'], sorted_sat_17['Participation'],)
plt.title('Participation by State')
plt.xlabel('Participation Percent')
plt.ylabel('State')
;
# Out:
# ''

# %%
sat_17.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %%
sum(sat_17['Math'])/51
# Out:
# 547.6274509803922

# %%
scatter_matrix(sat_17, figsize = (15, 10));

# %%
sorted_act_17 = act_17.sort_values('Participation')

plt.figure(figsize = (15,10))
plt.barh(sorted_act_17['State'], sorted_act_17['Participation'],)
plt.title('Participation by State')
plt.xlabel('Participation Percent')
plt.ylabel('State')
;
# Out:
# ''

# %%
scatter_matrix(act_17, figsize = (15, 10));

# %%
act_17.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
act_17.sort_values('Science').head()
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 21        Maryland           28%     23.3  23.1     24.2      2.3      23.6
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1

# %% [markdown]
# #### 3. Look for errors in the data

# %%
# ACT has a national average, but SAT doesn't.
# SAT & ACT 2017 Participation & ACT Composite are stored as strings, not integers.
# The averages pulled from my dataset won't match the website's because they have the individual student data and mine is state totals.
# The minimum for math is off due to Maryland showing only 52 (real value is 524)
# Maryland Science minimum looks off at only 2.3 (real value is 23.2)
# Wyoming ACT Composite score has an "x" at the end
# Total SAT scores don't always match sum of Writing and Math by state

# %%
# from class today:
# 1) to rename columns --  first create a dictionary, then run rename
#    df.rename(columns = new_columns_dict, inplace = True)

# 2) to change object data type to number -- use pd.to_numeric
#    df['column_name'] = pd.to_numeric(df['column_name'], downcast = 'integer')

# 3) use heatmap for correlations:
#    plt.figure(figsize=(10, 8))
#    plt.title('Correlation plot')
#    mask = np.zeros_like(df.corr())
#    mask[np.triu_indices_from(mask)] = True
#    sns.heatmap(df.corr(), mask=mask, cmap='vlag', annot=True);

# 4) pairplot
#    sns.pairplot(data = df, corner = True, hue = 'SOME COLUMN');

# %% [markdown]
# #### 3a. Hint - Are there any obvious issues with the observations?
#
# **What is the minimum *possible* value for each test/subtest? What is the maximum *possible* value?**
#
# Consider comparing any questionable values to the sources of your data:
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/)
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows)

# %% [markdown]
# #### 4. Fix any errors you identified

# %%
act_17.loc[21] = act_17.loc[21].replace(2.3, 23.2)

# %%
act_17.loc[21]
# Out:
# State            Maryland
# Participation         28%
# English              23.3
# Math                 23.1
# Reading              24.2
# Science              23.2
# Composite            23.6
# Name: 21, dtype: object

# %%
sat_17.loc[20] = sat_17.loc[20].replace(52, 524)

# %%
sat_17.loc[20]
# Out:
# State                                 Maryland
# Participation                              69%
# Evidence-Based Reading and Writing         536
# Math                                       524
# Total                                     1060
# Name: 20, dtype: object

# %%
act_17.loc[51, 'Composite'] = act_17.loc[51, 'Composite'].replace('x', '')

# %%
# inspired by code from https://stackoverflow.com/questions/25669588/convert-percent-string-to-float-in-pandas-read-csv

act_17['Participation'] = act_17['Participation'].str.rstrip('%').astype('float') / 100.0

# %%
sat_17['Participation'] = sat_17['Participation'].str.rstrip('%').astype('float') / 100.0

# %%
#used from EDA lesson on 3/31

act_17['Composite'] = pd.to_numeric(act_17['Composite'], downcast = 'integer')

# %% [markdown]
# #### 5. Fix any incorrect data types

# %%
act_17.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
sat_17.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing      int64
# Math                                    int64
# Total                                   int64
# dtype: object

# %% [markdown]
# #### 6. Rename Columns
# Change the names of the columns to more expressive names so that you can tell the difference between the SAT columns and the ACT columns. Remember that you have data from multiple years.
#
# - Column names should be all lowercase
# - Column names should not contain spaces
# - Column names should be unique and informative

# %%
act_17.columns
# Out:
# Index(['State', 'Participation', 'English', 'Math', 'Reading', 'Science',
#        'Composite'],
#       dtype='object')

# %%
act17_new_columns = {'State': 'state', 'Participation': 'act17_participation', 'English': 'act17_english', 'Math': 'act17_math', 'Reading': 'act17_reading', 'Science':'act17_science', 'Composite': 'act17_composite'}

act_17.rename(columns = act17_new_columns, inplace = True)

# %%
act_17.head()
# Out:
#       state  act17_participation  act17_english  act17_math  act17_reading  \
# 0  National                 0.60           20.3        20.7           21.4
# 1   Alabama                 1.00           18.9        18.4           19.7
# 2    Alaska                 0.65           18.7        19.8           20.4
# 3   Arizona                 0.62           18.6        19.8           20.1
# 4  Arkansas                 1.00           18.9        19.0           19.7
#
#    act17_science  act17_composite
# 0           21.0             21.0
# 1           19.4             19.2
# 2           19.9             19.8
# 3           19.8             19.7
# 4           19.5             19.4

# %%
sat_17.columns
# Out:
# Index(['State', 'Participation', 'Evidence-Based Reading and Writing', 'Math',
#        'Total'],
#       dtype='object')

# %%
sat17_new_columns = {'State': 'state', 'Participation': 'sat17_participation', 'Evidence-Based Reading and Writing': 'sat17_reading_writing', 'Math': 'sat17_math', 'Total': 'sat17_total'}

sat_17.rename(columns = sat17_new_columns, inplace = True)

# %%
sat_17.head()
# Out:
#         state  sat17_participation  sat17_reading_writing  sat17_math  \
# 0     Alabama                 0.05                    593         572
# 1      Alaska                 0.38                    547         533
# 2     Arizona                 0.30                    563         553
# 3    Arkansas                 0.03                    614         594
# 4  California                 0.53                    531         524
#
#    sat17_total
# 0         1165
# 1         1080
# 2         1116
# 3         1208
# 4         1055

# %% [markdown]
# #### 7. Create a data dictionary
#
# Now that you've fixed our data and given it appropriate names, create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|ACT/SAT|The list of states in the study, includes all 50 states plus Washington DC.|
# |**sat17_participation**|*float*|SAT 2017|The 2017 SAT participation rate by state (shown as a fraction of 1).|
# |**sat17_total**|*integer*|SAT 2017|The 2017 SAT average Total combined (sum of Math and Evidence-Based Reading and Writing) score by state.|
# |**act17_participation**|*float*|ACT 2017|The 2017 ACT participation rate by state (shown as a fraction of 1).|
# |**act17_composite**|*float*|ACT 2017|The 2017 ACT average Composite score by state. The Composite score is the average of your the test scores, rounded to the nearest whole number.|
# |**sat18_participation**|*float*|SAT 2018|The 2018 SAT participation rate by state (shown as a fraction of 1).|
# |**sat18_total**|*integer*|SAT 2018|The 2018 SAT average Total combined (sum of Math and Evidence-Based Reading and Writing) score by state.|
# |**act18_participation**|*float*|ACT 2018|The 2018 ACT participation rate by state (shown as a fraction of 1).|
# |**act18_composite**|*float*|ACT 2018|The 2018 ACT average Composite score by state. The Composite score is the average of your the test scores, rounded to the nearest whole number.|
# |**sat19_participation**|*float*|SAT 2019|The 2019 SAT participation rate by state (shown as a fraction of 1).|
# |**sat19_total**|*integer*|SAT 2019|The 2019 SAT average Total combined (sum of Math and Evidence-Based Reading and Writing) score by state.|
# |**act19_participation**|*float*|ACT 2019|The 2019 ACT participation rate by state (shown as a fraction of 1).|
# |**act19_composite**|*float*|ACT 2019|The 2019 ACT average Composite score by state. The Composite score is the average of your the test scores, rounded to the nearest whole number.|

# %% [markdown]
# #### 8. Drop any unnecessary rows

# %%
act_17.drop(0, inplace = True)

# %%
act_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 1 to 51
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   state                51 non-null     object
#  1   act17_participation  51 non-null     float64
#  2   act17_english        51 non-null     float64
#  3   act17_math           51 non-null     float64
#  4   act17_reading        51 non-null     float64
#  5   act17_science        51 non-null     float64
#  6   act17_composite      51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# #### 9. Merge Dataframes
#
# Join the 2017 ACT and SAT DataFrames using the _state_ in each DataFrame as the key.

# %%
combined_2017 = pd.merge(
    left = sat_17,
    right = act_17,
    how = 'inner',
    on = 'state')

# %%
combined_2017
# Out:
#                    state  sat17_participation  sat17_reading_writing  \
# 0                Alabama                 0.05                    593
# 1                 Alaska                 0.38                    547
# 2                Arizona                 0.30                    563
# 3               Arkansas                 0.03                    614
# 4             California                 0.53                    531
# 5               Colorado                 0.11                    606
# 6            Connecticut                 1.00                    530
# 7               Delaware                 1.00                    503
# 8   District of Columbia                 1.00                    482
# 9                Florida                 0.83                    520
# 10               Georgia                 0.61                    535
# 11                Hawaii                 0.55                    544
# 12                 Idaho                 0.93                    513
# ...

# %% [markdown]
# #### 10. Save your cleaned, merged dataframe
#
# Use a relative path to save your data as `combined_2017.csv`.

# %%
combined_2017.to_csv('../data/combined_2017.csv')

# %% [markdown]
# ## 2018 & 2019 Data Import and Cleaning

# %% [markdown]
# Read in the 2018 data. Inspect and clean. Save. Do the same with the 2019 data.

# %%
sat_18 = pd.read_csv('../data/sat_2018.csv')

# %%
sat_18.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
act_18 = pd.read_csv('../data/act_2018.csv')

# %%
act_18.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_18.drop(20, inplace = True)

# %%
act_18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   Composite      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
sat_19 = pd.read_csv('../data/sat_2019.csv', encoding = 'ANSI')

# %%
sat_19.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
sat_19['Participation Rate'] = sat_19['Participation Rate'].replace('Ñ',np.nan)

# %%
sat_19 = sat_19.dropna()

# %%
sat_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               51 non-null     object
#  1   Participation Rate  51 non-null     object
#  2   EBRW                51 non-null     int64
#  3   Math                51 non-null     int64
#  4   Total               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.4+ KB

# %%
act_19 = pd.read_csv('../data/act_2019.csv')

# %%
act_19.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_19.drop(51, inplace = True)

# %%
act_19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  51 non-null     object
#  2   Composite      51 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.6+ KB

# %%
act_18['Participation'] = act_18['Participation'].str.rstrip('%').astype('float') / 100.0
act_19['Participation'] = act_19['Participation'].str.rstrip('%').astype('float') / 100.0
sat_18['Participation'] = sat_18['Participation'].str.rstrip('%').astype('float') / 100.0
sat_19['Participation Rate'] = sat_19['Participation Rate'].str.rstrip('%').astype('float') / 100.0

# %%
sat_19.columns
# Out:
# Index(['State', 'Participation Rate', 'EBRW', 'Math', 'Total'], dtype='object')

# %%
act18_new_columns = {'State': 'state', 'Participation': 'act18_participation', 'Composite': 'act18_composite'}

act_18.rename(columns = act18_new_columns, inplace = True)

# %%
act19_new_columns = {'State': 'state', 'Participation': 'act19_participation', 'Composite': 'act19_composite'}

act_19.rename(columns = act19_new_columns, inplace = True)

# %%
sat18_new_columns = {'State': 'state', 'Participation': 'sat18_participation', 'Evidence-Based Reading and Writing': 'sat18_reading_writing', 'Math': 'sat18_math', 'Total': 'sat18_total'}

sat_18.rename(columns = sat18_new_columns, inplace = True)

# %%
sat19_new_columns = {'State': 'state', 'Participation Rate': 'sat19_participation', 'EBRW': 'sat19_reading_writing', 'Math': 'sat19_math', 'Total': 'sat19_total'}

sat_19.rename(columns = sat19_new_columns, inplace = True)

# %%
act_18['state'] = act_18['state'].replace('District of columbia', 'District of Columbia')

# %% [markdown]
# ## Combine your 2017, 2018, and 2019 data into a single dataframe
# Joining on state names should work, assuming you formatted all your state names identically. Make sure none of your columns (other than state) have identical names.
#
# Do yourself a favor and decide if you're encoding participation rates as floats or integers and standardize this across your datasets.
#
# Save the contents of this merged DataFrame as `final.csv`.
#
# **Use this combined DataFrame for the remainder of the project**.

# %%
combined_2018 = pd.merge(
    left = sat_18,
    right = act_18,
    how = 'inner',
    on = 'state')

# %%
combined_2018
# Out:
#                    state  sat18_participation  sat18_reading_writing  \
# 0                Alabama                 0.06                    595
# 1                 Alaska                 0.43                    562
# 2                Arizona                 0.29                    577
# 3               Arkansas                 0.05                    592
# 4             California                 0.60                    540
# 5               Colorado                 1.00                    519
# 6            Connecticut                 1.00                    535
# 7               Delaware                 1.00                    505
# 8   District of Columbia                 0.92                    497
# 9                Florida                 0.56                    550
# 10               Georgia                 0.70                    542
# 11                Hawaii                 0.56                    480
# 12                 Idaho                 1.00                    508
# ...

# %%
combined_2018.to_csv('../data/combined_2018.csv')

# %%
combined_2019 = pd.merge(
    left = sat_19,
    right = act_19,
    how = 'inner',
    on = 'state')

# %%
combined_2019
# Out:
#                    state  sat19_participation  sat19_reading_writing  \
# 0                Alabama                 0.07                    583
# 1                 Alaska                 0.41                    556
# 2                Arizona                 0.31                    569
# 3               Arkansas                 0.06                    582
# 4             California                 0.63                    534
# 5               Colorado                 1.00                    518
# 6            Connecticut                 1.00                    529
# 7               Delaware                 1.00                    499
# 8   District of Columbia                 0.94                    495
# 9                Florida                 1.00                    516
# 10               Georgia                 0.71                    538
# 11                Hawaii                 0.54                    550
# 12                 Idaho                 1.00                    505
# ...

# %%
combined_2019.to_csv('../data/combined_2019.csv')

# %%
# help from https://stackoverflow.com/questions/23668427/pandas-three-way-joining-multiple-dataframes-on-columns
from functools import reduce

dfs = [combined_2017, combined_2018, combined_2019]
final = reduce(lambda left, right:pd.merge(left,right,on='state'), dfs)

# %%
final.to_csv('../data/final.csv')

# %%
final.head()
# Out:
#         state  sat17_participation  sat17_reading_writing  sat17_math  \
# 0     Alabama                 0.05                    593         572
# 1      Alaska                 0.38                    547         533
# 2     Arizona                 0.30                    563         553
# 3    Arkansas                 0.03                    614         594
# 4  California                 0.53                    531         524
#
#    sat17_total  act17_participation  act17_english  act17_math  act17_reading  \
# 0         1165                 1.00           18.9        18.4           19.7
# 1         1080                 0.65           18.7        19.8           20.4
# 2         1116                 0.62           18.6        19.8           20.1
# 3         1208                 1.00           18.9        19.0           19.7
# 4         1055                 0.31           22.5        22.7           23.1
#
#    act17_science  ...  sat18_math  sat18_total  act18_participation  \
# ...

# %%
total_scores = final.drop(['act17_english', 'act17_math', 'act17_reading', 'act17_science', 'sat17_math', 'sat17_reading_writing', 'sat18_math', 'sat18_reading_writing', 'sat19_math', 'sat19_reading_writing'], axis = 'columns')

# %%
total_scores.to_csv('../data/Total_Scores.csv')

# %% [markdown]
# # Exploratory Data Analysis
#
#
# ### Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
total_scores.describe().T
# Out:
#                      count         mean        std     min       25%      50%  \
# sat17_participation   51.0     0.398039   0.352766    0.02     0.040     0.38
# sat17_total           51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# act17_participation   51.0     0.652549   0.321408    0.08     0.310     0.69
# act17_composite       51.0    21.519608   2.020695   17.80    19.800    21.40
# sat18_participation   51.0     0.457451   0.373143    0.02     0.045     0.52
# sat18_total           51.0  1120.019608  94.155083  977.00  1057.500  1098.00
# act18_participation   51.0     0.617255   0.340371    0.07     0.285     0.66
# act18_composite       51.0    21.496078   2.111583   17.70    19.950    21.30
# sat19_participation   51.0     0.490588   0.387476    0.02     0.055     0.54
# sat19_total           51.0  1113.078431  97.197910  943.00  1038.000  1097.00
# act19_participation   51.0     0.586667   0.345159    0.06     0.245     0.54
# ...

# %% [markdown]
# ## Investigate trends in the data
# Using sorting to consider the following questions:
#
# - Which states have the highest and lowest participation rates for each test for each year?
# - Which states have the highest and lowest mean total/composite scores for each test for each year?
# - Which states have large changes in participation or scores?
#
# Based on what you've just observed, have you identified any states that you're especially interested in? If so, why?

# %%
print(total_scores.sort_values(by = 'sat17_participation').reset_index().loc[:5,['state','sat17_participation']])
print(total_scores.sort_values(by = 'sat18_participation').reset_index().loc[:5,['state','sat18_participation']])
print(total_scores.sort_values(by = 'sat19_participation').reset_index().loc[:5,['state','sat19_participation']])
print(total_scores.sort_values(by = 'sat17_participation',ascending = False).reset_index().loc[:5,['state','sat17_participation']])
print(total_scores.sort_values(by = 'sat18_participation',ascending = False).reset_index().loc[:5,['state','sat18_participation']])
print(total_scores.sort_values(by = 'sat19_participation',ascending = False).reset_index().loc[:5,['state','sat19_participation']])
# Out:
#           state  sat17_participation
# 0  North Dakota                 0.02
# 1   Mississippi                 0.02
# 2          Iowa                 0.02
# 3      Missouri                 0.03
# 4          Utah                 0.03
# 5  South Dakota                 0.03
#           state  sat18_participation
# 0  North Dakota                 0.02
# 1       Wyoming                 0.03
# 2  South Dakota                 0.03
# 3      Nebraska                 0.03
# 4     Wisconsin                 0.03
# 5   Mississippi                 0.03
#           state  sat19_participation
# 0  North Dakota                 0.02
# 1       Wyoming                 0.03
# 2  South Dakota                 0.03
# 3      Nebraska                 0.03
# 4     Wisconsin                 0.03
# 5   Mississippi                 0.03
#                   state  sat17_participation
# 0  District of Columbia                 1.00
# 1              Michigan                 1.00
# ...

# %%
print(total_scores.sort_values(by = 'act17_participation').reset_index().loc[:5,['state','act17_participation']])
print(total_scores.sort_values(by = 'act18_participation').reset_index().loc[:5,['state','act18_participation']])
print(total_scores.sort_values(by = 'act19_participation').reset_index().loc[:5,['state','act19_participation']])
print(total_scores.sort_values(by = 'act17_participation',ascending = False).reset_index().loc[:5,['state','act17_participation']])
print(total_scores.sort_values(by = 'act18_participation',ascending = False).reset_index().loc[:5,['state','act18_participation']])
print(total_scores.sort_values(by = 'act19_participation',ascending = False).reset_index().loc[:5,['state','act19_participation']])
# Out:
#            state  act17_participation
# 0          Maine                 0.08
# 1  New Hampshire                 0.18
# 2       Delaware                 0.18
# 3   Rhode Island                 0.21
# 4   Pennsylvania                 0.23
# 5       Maryland                 0.28
#            state  act18_participation
# 0          Maine                 0.07
# 1   Rhode Island                 0.15
# 2  New Hampshire                 0.16
# 3       Delaware                 0.17
# 4   Pennsylvania                 0.20
# 5       Michigan                 0.22
#            state  act19_participation
# 0          Maine                 0.06
# 1   Rhode Island                 0.12
# 2       Delaware                 0.13
# 3  New Hampshire                 0.14
# 4   Pennsylvania                 0.17
# 5       Michigan                 0.19
#             state  act17_participation
# 0         Alabama                  1.0
# 1        Kentucky                  1.0
# ...

# %%
print(total_scores.sort_values(by = 'sat17_total').reset_index().loc[:5,['state','sat17_total']])
print(total_scores.sort_values(by = 'sat18_total').reset_index().loc[:5,['state','sat18_total']])
print(total_scores.sort_values(by = 'sat19_total').reset_index().loc[:5,['state','sat19_total']])
print(total_scores.sort_values(by = 'sat17_total',ascending = False).reset_index().loc[:5,['state','sat17_total']])
print(total_scores.sort_values(by = 'sat18_total',ascending = False).reset_index().loc[:5,['state','sat18_total']])
print(total_scores.sort_values(by = 'sat19_total',ascending = False).reset_index().loc[:5,['state','sat19_total']])
# Out:
#                   state  sat17_total
# 0  District of Columbia          950
# 1              Delaware          996
# 2                 Idaho         1005
# 3              Michigan         1005
# 4                 Maine         1012
# 5               Florida         1017
#                   state  sat18_total
# 0  District of Columbia          977
# 1              Delaware          998
# 2         West Virginia          999
# 3                 Idaho         1001
# 4                  Utah         1010
# 5                Hawaii         1010
#                   state  sat19_total
# 0         West Virginia          943
# 1              Oklahoma          963
# 2  District of Columbia          975
# 3              Delaware          985
# 4                 Idaho          993
# 5          Rhode Island          995
#           state  sat17_total
# 0     Minnesota         1295
# 1     Wisconsin         1291
# 2          Iowa         1275
# 3      Missouri         1271
# ...

# %%
print(total_scores.sort_values(by = 'act17_composite').reset_index().loc[:5,['state','act17_composite']])
print(total_scores.sort_values(by = 'act18_composite').reset_index().loc[:5,['state','act18_composite']])
print(total_scores.sort_values(by = 'act19_composite').reset_index().loc[:5,['state','act19_composite']])
print(total_scores.sort_values(by = 'act17_composite',ascending = False).reset_index().loc[:5,['state','act17_composite']])
print(total_scores.sort_values(by = 'act18_composite',ascending = False).reset_index().loc[:5,['state','act18_composite']])
print(total_scores.sort_values(by = 'act19_composite',ascending = False).reset_index().loc[:5,['state','act19_composite']])
# Out:
#             state  act17_composite
# 0          Nevada             17.8
# 1     Mississippi             18.6
# 2  South Carolina             18.7
# 3          Hawaii             19.0
# 4  North Carolina             19.1
# 5         Alabama             19.2
#             state  act18_composite
# 0          Nevada             17.7
# 1  South Carolina             18.3
# 2     Mississippi             18.6
# 3          Hawaii             18.9
# 4         Alabama             19.1
# 5  North Carolina             19.1
#             state  act19_composite
# 0          Nevada             17.9
# 1     Mississippi             18.4
# 2  South Carolina             18.8
# 3       Louisiana             18.8
# 4         Alabama             18.9
# 5        Oklahoma             18.9
#                   state  act17_composite
# 0         New Hampshire             25.5
# 1         Massachusetts             25.4
# 2           Connecticut             25.2
# 3                 Maine             24.3
# ...

# %%
total_scores
# Out:
#                    state  sat17_participation  sat17_total  \
# 0                Alabama                 0.05         1165
# 1                 Alaska                 0.38         1080
# 2                Arizona                 0.30         1116
# 3               Arkansas                 0.03         1208
# 4             California                 0.53         1055
# 5               Colorado                 0.11         1201
# 6            Connecticut                 1.00         1041
# 7               Delaware                 1.00          996
# 8   District of Columbia                 1.00          950
# 9                Florida                 0.83         1017
# 10               Georgia                 0.61         1050
# 11                Hawaii                 0.55         1085
# 12                 Idaho                 0.93         1005
# 13              Illinois                 0.09         1115
# 14               Indiana                 0.63         1074
# ...

# %% [markdown]
# #### **States to look into and why:**
# ---
# ##### *On SAT Participation*
# * Why did DC go from 100% to falling out of top 5?
# * Which states required 100% participation all 3 years?
#     * <https://blog.prepscholar.com/which-states-require-the-sat>
#     * What were their scores?
#     * Did any state require testing in only partial of the 3 years? How did it affect scores?
# * Why do more states have 100% participation in 2019?
#     * <https://reports.collegeboard.org/archive/sat-suite-program-results/2018/sat-school-day>
# * What's with North Dakota only have 2% participation all 3 years?
# * Utah, Iowa, and Missouri left the 5 lowest participation - did they change a rule?
# * North Dakota & Mississippi consistently in lowest 5
# * Colorado switched from requiring ACT to SAT in 2018
#     * <https://www.coloradokids.org/wp-content/uploads/2016/01/ACTvsSAT_FINAL.pdf>
#
# ##### *On ACT Participation*
# * <https://magoosh.com/hs/sat/states-that-require-the-act-or-sat/>
# * Maine, New Hampshire, Delaware, Pennsylvania consistently in the bottom 5 participation - all northeastern states
#     * Maine is always the lowest participation
# * Alabama, Kentucky, Wisconsin, Utah consistently in the top 5 participation
# * In general the participation rates never fall as low as the SATs do
#
# ---
# ##### *On SAT Total Scores*
# * Minnesota, Wisconsin, Iowa, North Dakota consistently in the top 5 SAT scores
#     * North Dakota lowest participation & highest scores
# * DC & Idaho consistently in the lowest 5 SAT scores
# * Maine was in lowest 5 in 2017, but improved next 2 years
#
# ##### *On ACT Composite Scores*
# * Nevada & Alabama always the lowest
# * Connecticut, New Hampshire, Massachussets, New York always highest

# %% [markdown]
# States to look at for SATs: Rhode Island (started requiring 2018) DC, North Dakota, Maine

# %% [markdown]
# States to look at for ACTs: Maine, New Hampshire

# %% [markdown]
# ## Visualize the data
#
# There's not a magic recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Font size is easy to read on a slide
# - Plots demonstrate meaningful and valid relationships
# - Interpret plots to aid audience understanding
#
# Feel free to make functions to quickly plot relationships (e.g. if you want to make a lot of histograms).

# %% [markdown]
# #### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).

# %%
plt.figure(figsize=(10, 8))
plt.title('Correlation plot')
mask = np.zeros_like(total_scores.corr())
mask[np.triu_indices_from(mask)] = True
sns.heatmap(total_scores.corr(), mask=mask, cmap='vlag', annot=True)
;
# Out:
# ''

# %% [markdown]
# #### Use Seaborn's pairplot for relevant columns

# %%
combined_2017_totals = combined_2017.drop(['act17_english', 'act17_math', 'act17_reading', 'act17_science', 'sat17_math', 'sat17_reading_writing'], axis = 'columns')

# %%
combined_2018_totals = combined_2018.drop(['sat18_math', 'sat18_reading_writing'], axis = 'columns')

# %%
combined_2019_totals = combined_2019.drop(['sat19_math', 'sat19_reading_writing'], axis = 'columns')

# %%
plt.figure(figsize = (8, 8))
sns.pairplot(data = combined_2017_totals, corner = True);

# %%
plt.figure(figsize = (8, 8))
sns.pairplot(data = combined_2018_totals, corner = True);

# %%
plt.figure(figsize = (8, 8))
sns.pairplot(data = combined_2019_totals, corner = True);

# %% [markdown]
# #### Plot and interpret histograms for important columns

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 4))
ax[0].hist(total_scores['act17_participation'], bins = 20)
ax[0].set_title('2017 ACT Participation')
ax[0].set_xlabel('Participation as Fraction of 1')
ax[0].set_ylabel('Frequency')
ax[0].set_ylim(0, 20)

ax[1].hist(total_scores['act18_participation'], bins = 20)
ax[1].set_title('2018 ACT Participation')
ax[1].set_xlabel('Participation as Fraction of 1')
ax[1].set_ylabel('Frequency')
ax[1].set_ylim(0, 20)

ax[2].hist(total_scores['act19_participation'], bins = 20)
ax[2].set_title('2019 ACT Participation')
ax[2].set_xlabel('Participation as Fraction of 1')
ax[2].set_ylabel('Frequency')
ax[2].set_ylim(0, 20)

fig.suptitle('ACT Participation')

;
# Out:
# ''

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 4))
ax[0].hist(total_scores['sat17_participation'], bins = 20)
ax[0].set_title('2017 SAT Participation')
ax[0].set_xlabel('Participation as Fraction of 1')
ax[0].set_ylabel('Frequency')
ax[0].set_ylim(0, 20)

ax[1].hist(total_scores['sat18_participation'], bins = 20)
ax[1].set_title('2018 SAT Participation')
ax[1].set_xlabel('Participation as Fraction of 1')
ax[1].set_ylabel('Frequency')
ax[1].set_ylim(0, 20)

ax[2].hist(total_scores['sat19_participation'], bins = 20)
ax[2].set_title('2019 SAT Participation')
ax[2].set_xlabel('Participation as Fraction of 1')
ax[2].set_ylabel('Frequency')
ax[2].set_ylim(0, 20)

fig.suptitle('SAT Participation')

;
# Out:
# ''

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 4))
ax[0].hist(total_scores['act17_composite'], bins = 10)
ax[0].set_title('2017 ACT Average Composite Score')
ax[0].set_xlabel('Participation as Fraction of 1')
ax[0].set_ylabel('Frequency')
ax[0].set_ylim(0, 12)

ax[1].hist(total_scores['act18_composite'], bins = 10)
ax[1].set_title('2018 ACT Average Composite Score')
ax[1].set_xlabel('Participation as Fraction of 1')
ax[1].set_ylabel('Frequency')
ax[1].set_ylim(0, 12)

ax[2].hist(total_scores['act19_composite'], bins = 10)
ax[2].set_title('2019 ACT Average Composite Score')
ax[2].set_xlabel('Participation as Fraction of 1')
ax[2].set_ylabel('Frequency')
ax[2].set_ylim(0, 12)

fig.suptitle('ACT Composite Scores')

;
# Out:
# ''

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 3, figsize = (20, 4))
ax[0].hist(total_scores['sat17_total'], bins = 10)
ax[0].set_title('2017 SAT Average Total Score')
ax[0].set_xlabel('Participation as Fraction of 1')
ax[0].set_ylabel('Frequency')
ax[0].set_ylim(0, 15)

ax[1].hist(total_scores['sat18_total'], bins = 10)
ax[1].set_title('2018 SAT Average Total Score')
ax[1].set_xlabel('Participation as Fraction of 1')
ax[1].set_ylabel('Frequency')
ax[1].set_ylim(0, 15)

ax[2].hist(total_scores['sat19_total'], bins = 10)
ax[2].set_title('2019 SAT Average Total Score')
ax[2].set_xlabel('Participation as Fraction of 1')
ax[2].set_ylabel('Frequency')
ax[2].set_ylim(0, 15)

fig.suptitle('SAT Total Scores')

;
# Out:
# ''

# %%
plt.figure(figsize = (8, 6))

plt.hist(total_scores['act17_participation'],  bins = 10, color = 'mediumpurple', label = 'ACT')
plt.hist(total_scores['sat17_participation'], bins = 10, color = 'forestgreen', label = 'SAT', fc=(0.008, 0.42, 0.2, 0.7))

plt.axvline(total_scores['sat17_participation'].mean(), color='forestgreen', linestyle='dashed', linewidth=2)
plt.axvline(total_scores['act17_participation'].mean(), color='mediumpurple', linestyle='dashed', linewidth=2)

plt.ylim(0, 25)
plt.xlabel('Participation as a Fraction of 1')
plt.ylabel('Frequency')
plt.title('SAT vs ACT Participation 2017')
plt.legend(loc = 1)
plt.savefig('SAT_ACT_Part_2017')

;
# Out:
# ''

# %%
total_scores[total_scores['sat17_participation'] > .90].describe()
# Out:
#        sat17_participation  sat17_total  act17_participation  act17_composite  \
# count             7.000000     7.000000             7.000000         7.000000
# mean              0.977143  1008.714286             0.248571        24.242857
# std               0.029841    33.074231             0.104631         1.026088
# min               0.930000   950.000000             0.080000        22.300000
# 25%               0.955000  1000.500000             0.180000        24.100000
# 50%               1.000000  1005.000000             0.290000        24.200000
# 75%               1.000000  1026.500000             0.315000        24.750000
# max               1.000000  1052.000000             0.380000        25.500000
#
#        sat18_participation  sat18_total  act18_participation  act18_composite  \
# count             7.000000     7.000000             7.000000         7.000000
# mean              0.981429  1016.571429             0.222857        24.085714
# ...

# %%
plt.figure(figsize = (8, 6))

plt.hist(total_scores['act19_participation'],  bins = 10, color = 'mediumpurple', label = 'ACT')
plt.hist(total_scores['sat19_participation'], bins = 10, color = 'forestgreen', label = 'SAT', fc=(0.008, 0.42, 0.2, 0.7))

plt.axvline(total_scores['sat19_participation'].mean(), color='forestgreen', linestyle='dashed', linewidth=2)
plt.axvline(total_scores['act19_participation'].mean(), color='mediumpurple', linestyle='dashed', linewidth=2)

plt.ylim(0, 25)
plt.xlabel('Participation as a Fraction of 1')
plt.ylabel('Frequency')
plt.title('SAT vs ACT Participation 2019')
plt.legend()
plt.savefig('SAT_ACT_Part_2019')

;
# Out:
# ''

# %% [markdown]
# #### Plot and interpret scatter plots for import columns

# %%
plt.figure(figsize = (8, 6))
plt.scatter(total_scores['sat17_participation'], total_scores['sat17_total'], label = '2017', )
plt.scatter(total_scores['sat18_participation'], total_scores['sat18_total'], label = '2018')
plt.scatter(total_scores['sat19_participation'], total_scores['sat19_total'], label = '2019')
plt.xlabel('Participation as a Fraction of 1')
plt.ylabel('Average Total Score')
plt.title('SAT Average Total Scores and Participation')
plt.legend()
plt.savefig('SAT_scores_part.png')

;
# Out:
# ''

# %%
plt.figure(figsize = (10, 7))
plt.scatter(total_scores['act17_participation'], total_scores['act17_composite'], label = '2017')
plt.scatter(total_scores['act18_participation'], total_scores['act17_composite'], label = '2018')
plt.scatter(total_scores['act19_participation'], total_scores['act17_composite'], label = '2019')
plt.xlabel('Participation as a Fraction of 1')
plt.ylabel('Average Composite Score')
plt.title('ACT Average Composite Scores and Participation')
plt.legend()
plt.savefig('ACT_scores_part.png', dpi = 100)

;
# Out:
# ''

# %%
plt.figure(figsize = (10, 7))
plt.scatter(total_scores['act17_participation'], total_scores['sat17_participation'], label = '2017')
plt.scatter(total_scores['act18_participation'], total_scores['sat18_participation'], label = '2018')
plt.scatter(total_scores['act19_participation'], total_scores['sat19_participation'], label = '2019')
plt.xlabel('ACT Participation')
plt.ylabel('SAT Participation')
plt.legend()
plt.title('ACT vs SAT Participation')
plt.savefig('ACT_vs_SAT', dpi = 100)

;
# Out:
# ''

# %% [markdown]
# #### Plot and interpret boxplots for important columns

# %%
act_participation = pd.DataFrame(data =  [total_scores['act17_participation'],
                                         total_scores['act18_participation'],
                                         total_scores['act19_participation']]).T
                                          
sat_participation = pd.DataFrame(data =  [total_scores['sat17_participation'],
                                         total_scores['sat18_participation'],
                                         total_scores['sat19_participation']]).T

act_scores = pd.DataFrame(data =  [total_scores['act17_composite'],
                                   total_scores['act18_composite'],
                                   total_scores['act19_composite']]).T
                                   
                                   
sat_scores = pd.DataFrame(data =  [total_scores['sat17_total'],
                                   total_scores['sat18_total'],
                                   total_scores['sat19_total']]).T


fig, ax = plt.subplots(nrows = 1, ncols = 4, figsize = (25, 5))
ax[0].boxplot(act_participation, labels = ('2017', '2018', '2019'))
ax[0].set_title('ACT Participation Rates')
ax[0].set_xlabel('Year')
ax[0].set_ylabel('Percentage as a Fraction of 1')

ax[1].boxplot(act_scores, labels = ('2017', '2018', '2019'))
ax[1].set_title('ACT Scores')
ax[1].set_xlabel('Year')
ax[1].set_ylabel('Average Total Score')

ax[2].boxplot(sat_participation, labels = ('2017', '2018', '2019'))
ax[2].set_title('SAT Participation Rates')
ax[2].set_xlabel('Year')
ax[2].set_ylabel('Percentage as a Fraction of 1')

ax[3].boxplot(sat_scores, labels = ('2017', '2018', '2019'))
ax[3].set_title('SAT Scores')
ax[3].set_xlabel('Year')
ax[3].set_ylabel('Average Total Score')

# ax[0].box(figsize = (10, 8))

;
# Out:
# ''

# %% [markdown]
# #### Feel free to create and interpret additional plots

# %%
sat_participation.mean()
# Out:
# sat17_participation    0.398039
# sat18_participation    0.457451
# sat19_participation    0.490588
# dtype: float64

# %%
sat_scores.mean()
# Out:
# sat17_total    1126.098039
# sat18_total    1120.019608
# sat19_total    1113.078431
# dtype: float64

# %%
total_scores.describe()
# Out:
#        sat17_participation  sat17_total  act17_participation  act17_composite  \
# count            51.000000    51.000000            51.000000        51.000000
# mean              0.398039  1126.098039             0.652549        21.519608
# std               0.352766    92.494812             0.321408         2.020695
# min               0.020000   950.000000             0.080000        17.800000
# 25%               0.040000  1055.500000             0.310000        19.800000
# 50%               0.380000  1107.000000             0.690000        21.400000
# 75%               0.660000  1212.000000             1.000000        23.600000
# max               1.000000  1295.000000             1.000000        25.500000
#
#        sat18_participation  sat18_total  act18_participation  act18_composite  \
# count            51.000000    51.000000            51.000000        51.000000
# mean              0.457451  1120.019608             0.617255        21.496078
# ...

# %%
# https://cmdlinetips.com/2019/10/how-to-make-a-plot-with-two-different-y-axis-in-python-with-matplotlib/
    

average_sat_participation = sat_participation.mean()
fig, ax = plt.subplots(figsize = (8,6))
xlabels = ['2017','2018', '2019']
ax.bar(xlabels, average_sat_participation, color = 'skyblue', label = 'Participation')
ax.set_ylim(0,.7)
ax.set_title('SAT Participation and Scores')
ax.set_ylabel('Participation as a Fraction of 1')
ax.set_xlabel('Year')

ax2=ax.twinx()
ax2.plot(xlabels, sat_scores.mean(), color = 'firebrick', label = 'Average Total Score')
ax2.set_ylim(1055,1212)
ax2.set_ylabel('SAT Average Total Score')

lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

plt.savefig('SAT_scores_part_bar.png')
;
# Out:
# ''

# %%
average_act_participation = act_participation.mean()
fig, ax = plt.subplots()
xlabels = ['2017','2018', '2019']
ax.bar(xlabels, average_act_participation, color = 'skyblue')
ax.set_ylim(0, .8)
ax.set_title('ACT Participation and Scores')
ax.set_ylabel('Participation as a Fraction of 1')
ax.set_xlabel('Year')

ax2=ax.twinx()
ax2.plot(xlabels, act_scores.mean(), color = 'firebrick')
ax2.set_ylim(19.8,23.6)
ax2.set_ylabel('ACT Average Total Score')

lines3, labels3 = ax.get_legend_handles_labels()
lines4, labels4 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=0)

plt.savefig('ACT_scores_part.png')
;
# Out:
# ''

# %% [markdown]
# ## Outside Research

# %% [markdown]
# Based on your observations, choose **one or more** states that demonstrate interesting trends in their SAT and/or ACT participation rates. Spend some time doing outside research on state policies that might influence these rates, and summarize your findings below. **Feel free to go back and create new plots that highlight these states of interest**.
#
# If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. Make sure that you cite your sources.

# %%
total_scores.loc[39]
# Out:
# state                  Rhode Island
# sat17_participation            0.71
# sat17_total                    1062
# act17_participation            0.21
# act17_composite                  24
# sat18_participation            0.97
# sat18_total                    1018
# act18_participation            0.15
# act18_composite                24.2
# sat19_participation               1
# sat19_total                     995
# act19_participation            0.12
# act19_composite                24.7
# Name: 39, dtype: object

# %%
sat_participation.loc[39]
# Out:
# sat17_participation    0.71
# sat18_participation    0.97
# sat19_participation    1.00
# Name: 39, dtype: float64

# %%
ri_sat_participation = sat_participation.loc[39]
ri_sat_scores = pd.DataFrame(sat_scores.loc[39])

xlabels = ['2017','2018', '2019']
fig, ax = plt.subplots(figsize = (8, 6))
ax.bar(xlabels, ri_sat_participation, color = 'skyblue', label = 'Participation')
ax.set_ylim(0,1.1)
ax.set_title('Rhode Island SAT Participation and Scores')
ax.set_ylabel('Participation as a Fraction of 1')
ax.set_xlabel('Year')

ax2=ax.twinx()
ax2.plot(xlabels, ri_sat_scores, color = 'firebrick', label = 'Average Total Score')
ax2.set_ylim(950,1100)
ax2.set_ylabel('SAT Average Total Score')


lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=2)

plt.savefig('rhode_island.png')
;
# Out:
# ''

# %%
wv_sat_participation = sat_participation.loc[48]
wv_sat_scores = pd.DataFrame(sat_scores.loc[48])

xlabels = ['2017','2018', '2019']
fig, ax = plt.subplots(figsize = (8, 6))
ax.bar(xlabels, wv_sat_participation, color = 'skyblue', label = 'Participation')
ax.set_ylim(0,1.1)
ax.set_title('West Virginia SAT Participation and Scores')
ax.set_ylabel('Participation as a Fraction of 1')
ax.set_xlabel('Year')

ax2=ax.twinx()
ax2.plot(xlabels, ri_sat_scores, color = 'firebrick', label = 'Average Total Score')
ax2.set_ylim(950,1100)
ax2.set_ylabel('SAT Average Total Score')


lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=2)

plt.savefig('west_virginia.png')
;
# Out:
# ''

# %%
co_sat_participation = sat_participation.loc[5]
co_sat_scores = pd.DataFrame(sat_scores.loc[5])

xlabels = ['2017','2018', '2019']
fig, ax = plt.subplots(figsize = (10, 7))
ax.bar(xlabels, co_sat_participation, color = 'skyblue', label = 'Participation')
ax.set_ylim(0,1.1)
ax.set_title('Colorado SAT Participation and Scores')
ax.set_ylabel('Participation as a Fraction of 1')
ax.set_xlabel('Year')

ax2=ax.twinx()
ax2.plot(xlabels, ri_sat_scores, color = 'firebrick', label = 'Average Total Score')
ax2.set_ylim(950,1100)
ax2.set_ylabel('SAT Average Total Score')


lines, labels = ax.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(lines + lines2, labels + labels2, loc=2)

plt.savefig('colorado.png', dpi = 100)
;
# Out:
# ''

# %%
co_sat_participation
# Out:
# sat17_participation    0.11
# sat18_participation    1.00
# sat19_participation    1.00
# Name: 5, dtype: float64

# %%
#https://reports.collegeboard.org/archive/sat-suite-program-results/2018/sat-school-day

#leaving out West Virginia, Colorado and Rhode Island because rules appeared to change within the 3 years

required_states = total_scores.set_index('state')
required_states = required_states.loc[['Connecticut', 'Delaware', 'Idaho', 'Illinois', 'Maine', 'Michigan', 'New Hampshire', 'District of Columbia']]

# %%
non_required_states = total_scores.set_index('state').drop(['Colorado', 'Connecticut', 'Delaware', 'Idaho', 'Illinois', 'Maine', 'Michigan', 'New Hampshire', 'Rhode Island', 'West Virginia', 'District of Columbia'])

# %%
non_required_states.describe()
# Out:
#        sat17_participation  sat17_total  act17_participation  act17_composite  \
# count            40.000000    40.000000            40.000000          40.0000
# mean              0.310250  1147.650000             0.717750          21.0300
# std               0.287308    86.930432             0.294918           1.8145
# min               0.020000  1017.000000             0.230000          17.8000
# 25%               0.030000  1073.250000             0.387500          19.7000
# 50%               0.190000  1116.000000             0.775000          20.4500
# 75%               0.612500  1232.000000             1.000000          21.9250
# max               0.830000  1295.000000             1.000000          25.4000
#
#        sat18_participation  sat18_total  act18_participation  act18_composite  \
# count            40.000000    40.000000            40.000000        40.000000
# mean              0.330500  1148.600000             0.709750        20.885000
# ...

# %%
required_states.describe()
# Out:
#        sat17_participation  sat17_total  act17_participation  act17_composite  \
# count             8.000000     8.000000             8.000000         8.000000
# mean              0.866250  1022.000000             0.333750        23.887500
# std               0.314867    48.473852             0.259667         1.382996
# min               0.090000   950.000000             0.080000        21.400000
# 25%               0.945000  1002.750000             0.180000        23.650000
# 50%               0.980000  1008.500000             0.300000        24.150000
# 75%               1.000000  1043.750000             0.335000        24.525000
# max               1.000000  1115.000000             0.930000        25.500000
#
#        sat18_participation  sat18_total  act18_participation  act18_composite  \
# count             8.000000     8.000000             8.000000         8.000000
# mean              0.982500  1016.875000             0.248750        24.062500
# ...

# %%
required_states = required_states.reset_index()

# %%
#national averages:
#https://reports.collegeboard.org/pdf/2017-total-group-sat-suite-assessments-annual-report.pdf
#https://reports.collegeboard.org/pdf/2018-total-group-sat-suite-assessments-annual-report.pdf#page=4&zoom=auto,-63,775
#https://reports.collegeboard.org/pdf/2019-total-group-sat-suite-assessments-annual-report.pdf#page=4&zoom=100,-142,725


required_states_compare = pd.DataFrame({'SAT Required Participation': ['Required', 'Not Required', 'National Average'], 
                                '2017': [required_states['sat17_total'].mean(), non_required_states['sat17_total'].mean(), 1060], 
                                '2018': [required_states['sat18_total'].mean(), non_required_states['sat18_total'].mean(), 1068], 
                                '2019': [required_states['sat19_total'].mean(), non_required_states['sat19_total'].mean(), 1059]
                               
                               })

# %%
required_states_compare.set_index('SAT Required Participation', inplace = True)

# %%
required_states_compare
# Out:
#                                2017      2018      2019
# SAT Required Participation
# Required                    1022.00  1016.875  1010.875
# Not Required                1147.65  1148.600  1142.950
# National Average            1060.00  1068.000  1059.000

# %%
required_states_compare.T.plot(kind = 'bar', figsize = (8, 6))
plt.legend(loc = 4)
plt.ylim(800,1200)
plt.title('SAT Required Participation')
plt.xlabel('Year')
plt.ylabel('SAT Average Total Score')
plt.xticks(rotation = 0)

plt.savefig('participation_scores.png')

;
# Out:
# ''

# %%
colorado = pd.DataFrame(total_scores.loc[5]).T
montana = pd.DataFrame(total_scores.loc[26]).T
north_carolina = pd.DataFrame(total_scores.loc[33]).T
louisiana = pd.DataFrame(total_scores.loc[18]).T
missouri = pd.DataFrame(total_scores.loc[25]).T

# %%
co_mo = pd.concat([colorado, missouri])

# %%
co_mo
# Out:
#        state sat17_participation sat17_total act17_participation  \
# 5   Colorado                0.11        1201                   1
# 25  Missouri                0.03        1271                   1
#
#    act17_composite sat18_participation sat18_total act18_participation  \
# 5             20.8                   1        1025                 0.3
# 25            20.4                0.04        1262                   1
#
#    act18_composite sat19_participation sat19_total act19_participation  \
# 5             23.9                   1        1024                0.27
# 25              20                0.04        1236                0.82
#
#    act19_composite
# 5             23.8
# 25            20.8

# %%
total_scores[total_scores['act17_participation'] == 1]
# Out:
#              state  sat17_participation  sat17_total  act17_participation  \
# 0          Alabama                 0.05         1165                  1.0
# 3         Arkansas                 0.03         1208                  1.0
# 5         Colorado                 0.11         1201                  1.0
# 17        Kentucky                 0.04         1247                  1.0
# 18       Louisiana                 0.04         1198                  1.0
# 23       Minnesota                 0.03         1295                  1.0
# 24     Mississippi                 0.02         1242                  1.0
# 25        Missouri                 0.03         1271                  1.0
# 26         Montana                 0.10         1196                  1.0
# 28          Nevada                 0.26         1116                  1.0
# 33  North Carolina                 0.49         1081                  1.0
# 36        Oklahoma                 0.07         1047                  1.0
# ...

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are your 1 or 2 key recommendations for the College Board?
#
# Ensure that your recommendations make sense. These datasets have some limitations - think about granularity, aggregation, the relationships between populations size and rates. Consider the actual populations these data are drawn from. It is okay if your conclusions are tentative. You do not want to make unsupported jumps in logic.
