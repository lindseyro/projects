# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
# from category_encoders import OneHotEn

# %%
trials = pd.read_csv('./witch-trials-master/data/trials.csv')
trials.head()
# Out:
#    year  decade  century  tried  deaths city gadm.adm2 gadm.adm1 gadm.adm0  \
# 0   NaN    1520     1500      1     1.0  NaN       NaN       NaN   Estonia
# 1   NaN    1530     1500      1     1.0  NaN       NaN       NaN   Estonia
# 2   NaN    1540     1500      5     5.0  NaN       NaN       NaN   Estonia
# 3   NaN    1580     1500      7     5.0  NaN       NaN       NaN   Estonia
# 4   NaN    1590     1500     11     0.0  NaN       NaN       NaN   Estonia
#
#    lon  lat record.source
# 0  NaN  NaN  Madar (1990)
# 1  NaN  NaN  Madar (1990)
# 2  NaN  NaN  Madar (1990)
# 3  NaN  NaN  Madar (1990)
# 4  NaN  NaN  Madar (1990)

# %%
trials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10940 entries, 0 to 10939
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           10009 non-null  float64
#  1   decade         10940 non-null  int64
#  2   century        10940 non-null  int64
#  3   tried          10940 non-null  int64
#  4   deaths         7114 non-null   float64
#  5   city           5727 non-null   object
#  6   gadm.adm2      9893 non-null   object
#  7   gadm.adm1      10781 non-null  object
#  8   gadm.adm0      10940 non-null  object
#  9   lon            5137 non-null   float64
#  10  lat            5137 non-null   float64
#  11  record.source  10940 non-null  object
# dtypes: float64(4), int64(3), object(5)
# memory usage: 1.0+ MB

# %%
trials_clean = trials[trials['year'].notna()]

# %%
trials_clean.isna().sum()
# Out:
# year                0
# decade              0
# century             0
# tried               0
# deaths           3646
# city             4582
# gadm.adm2         703
# gadm.adm1          79
# gadm.adm0           0
# lon              5172
# lat              5172
# record.source       0
# dtype: int64

# %%
trials_clean = trials_clean[trials_clean['gadm.adm2'].notna()]
trials_clean.head()
# Out:
#        year  decade  century  tried  deaths city   gadm.adm2     gadm.adm1  \
# 230  1652.0    1650     1600      1     1.0  NaN      Geneve        Geneve
# 231  1782.0    1780     1700      1     1.0  NaN      Glarus        Glarus
# 258  1423.0    1420     1400      1     1.0  NaN      Sursee       Lucerne
# 303  1737.0    1730     1700      1     0.0  NaN    Willisau       Lucerne
# 390  1695.0    1690     1600      3     3.0  NaN  See-Gaster  Sankt Gallen
#
#        gadm.adm0  lon  lat record.source
# 230  Switzerland  NaN  NaN  Bader (1945)
# 231  Switzerland  NaN  NaN  Bader (1945)
# 258  Switzerland  NaN  NaN  Bader (1945)
# 303  Switzerland  NaN  NaN  Bader (1945)
# 390  Switzerland  NaN  NaN  Bader (1945)

# %%
trials_clean['year'] = trials_clean['year'].astype(int)

# %%
trials_clean['year_loc'] = trials_clean['year'].astype(str) + trials_clean['gadm.adm2']
trials_clean.head()
# Out:
#      year  decade  century  tried  deaths city   gadm.adm2     gadm.adm1  \
# 230  1652    1650     1600      1     1.0  NaN      Geneve        Geneve
# 231  1782    1780     1700      1     1.0  NaN      Glarus        Glarus
# 258  1423    1420     1400      1     1.0  NaN      Sursee       Lucerne
# 303  1737    1730     1700      1     0.0  NaN    Willisau       Lucerne
# 390  1695    1690     1600      3     3.0  NaN  See-Gaster  Sankt Gallen
#
#        gadm.adm0  lon  lat record.source        year_loc
# 230  Switzerland  NaN  NaN  Bader (1945)      1652Geneve
# 231  Switzerland  NaN  NaN  Bader (1945)      1782Glarus
# 258  Switzerland  NaN  NaN  Bader (1945)      1423Sursee
# 303  Switzerland  NaN  NaN  Bader (1945)    1737Willisau
# 390  Switzerland  NaN  NaN  Bader (1945)  1695See-Gaster

# %%
battles = pd.read_csv('./witch-trials-master/data/battles.csv')
battles.head()
# Out:
#            battle     month  year  decade  century            city  country  \
# 0           Trier    August  1522    1520     1500           Trier  Germany
# 1       Landstuhl     April  1523    1520     1500       Landstuhl  Germany
# 2  Donaueschingen  December  1524    1520     1500  Donaueschingen  Germany
# 3         Kempten     April  1525    1520     1500         Kempten  Germany
# 4        Leipheim     April  1525    1520     1500        Leipheim  Germany
#
#                     war war.theater        lon        lat gadm.adm0  \
# 0       Knights' Revolt         NaN   6.637143  49.749992   Germany
# 1       Knights' Revolt         NaN   7.570905  49.414146   Germany
# 2  German Peasants' War         NaN   8.497946  47.952152   Germany
# 3  German Peasants' War         NaN  10.315784  47.728570   Germany
# 4  German Peasants' War         NaN  10.226306  48.444412   Germany
#
#            gadm.adm1          gadm.adm2            source source.page
# 0    Rheinland-Pfalz              Trier  Hitchcock (1958)           1
# 1    Rheinland-Pfalz  Rheinhessen-Pfalz  Hitchcock (1958)           1
# 2  Baden-Wurttemberg           Freiburg     Miller (2003)          17
# 3             Bayern           Schwaben     Miller (2003)          14
# 4             Bayern           Schwaben     Miller (2003)          14

# %%
battles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   battle       424 non-null    object
#  1   month        379 non-null    object
#  2   year         424 non-null    int64
#  3   decade       424 non-null    int64
#  4   century      424 non-null    int64
#  5   city         424 non-null    object
#  6   country      424 non-null    object
#  7   war          424 non-null    object
#  8   war.theater  355 non-null    object
#  9   lon          424 non-null    float64
#  10  lat          424 non-null    float64
#  11  gadm.adm0    424 non-null    object
#  12  gadm.adm1    423 non-null    object
#  13  gadm.adm2    401 non-null    object
#  14  source       424 non-null    object
#  15  source.page  424 non-null    object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 53.1+ KB

# %%
battles_clean = battles[battles['gadm.adm2'].notna()]
battles_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 401 entries, 0 to 423
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   battle       401 non-null    object
#  1   month        362 non-null    object
#  2   year         401 non-null    int64
#  3   decade       401 non-null    int64
#  4   century      401 non-null    int64
#  5   city         401 non-null    object
#  6   country      401 non-null    object
#  7   war          401 non-null    object
#  8   war.theater  332 non-null    object
#  9   lon          401 non-null    float64
#  10  lat          401 non-null    float64
#  11  gadm.adm0    401 non-null    object
#  12  gadm.adm1    401 non-null    object
#  13  gadm.adm2    401 non-null    object
#  14  source       401 non-null    object
#  15  source.page  401 non-null    object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 53.3+ KB

# %%
battles_clean['year_loc'] = battles_clean['year'].astype(str) + battles_clean['gadm.adm2']
battles_clean.head()
# Out:
# <ipython-input-62-1bf744458618>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   battles_clean['year_loc'] = battles_clean['year'].astype(str) + battles_clean['gadm.adm2']
#            battle     month  year  decade  century            city  country  \
# 0           Trier    August  1522    1520     1500           Trier  Germany
# 1       Landstuhl     April  1523    1520     1500       Landstuhl  Germany
# 2  Donaueschingen  December  1524    1520     1500  Donaueschingen  Germany
# 3         Kempten     April  1525    1520     1500         Kempten  Germany
# 4        Leipheim     April  1525    1520     1500        Leipheim  Germany
#
#                     war war.theater        lon        lat gadm.adm0  \
# 0       Knights' Revolt         NaN   6.637143  49.749992   Germany
# 1       Knights' Revolt         NaN   7.570905  49.414146   Germany
# 2  German Peasants' War         NaN   8.497946  47.952152   Germany
# 3  German Peasants' War         NaN  10.315784  47.728570   Germany
# 4  German Peasants' War         NaN  10.226306  48.444412   Germany
#
#            gadm.adm1          gadm.adm2            source source.page  \
# 0    Rheinland-Pfalz              Trier  Hitchcock (1958)           1
# 1    Rheinland-Pfalz  Rheinhessen-Pfalz  Hitchcock (1958)           1
# 2  Baden-Wurttemberg           Freiburg     Miller (2003)          17
# 3             Bayern           Schwaben     Miller (2003)          14
# 4             Bayern           Schwaben     Miller (2003)          14
#
#                 year_loc
# 0              1522Trier
# 1  1523Rheinhessen-Pfalz
# 2           1524Freiburg
# 3           1525Schwaben
# 4           1525Schwaben

# %%
battles_clean['year_loc'].value_counts()
# Out:
# 1525Schwaben          4
# 1643Lincolnshire      3
# 1643West Yorkshire    3
# 1643Cornwall          3
# 1622Karlsruhe         3
#                      ..
# 1633Darmstadt         1
# 1646Livorno           1
# 1635Pavia             1
# 1646Nord              1
# 1645Dorset            1
# Name: year_loc, Length: 357, dtype: int64

# %%
battles_clean[battles_clean['year_loc'] == '1525Schwaben']
# Out:
#           battle   month  year  decade  century      city  country  \
# 3        Kempten   April  1525    1520     1500   Kempten  Germany
# 4       Leipheim   April  1525    1520     1500  Leipheim  Germany
# 15  Leubas River    July  1525    1520     1500    Leubas  Germany
# 18      Sulzberg  Spring  1525    1520     1500  Sulzberg  Germany
#
#                      war war.theater        lon        lat gadm.adm0  \
# 3   German Peasants' War         NaN  10.315784  47.728570   Germany
# 4   German Peasants' War         NaN  10.226306  48.444412   Germany
# 15  German Peasants' War         NaN  10.337123  47.763792   Germany
# 18  German Peasants' War         NaN  10.348092  47.660992   Germany
#
#    gadm.adm1 gadm.adm2         source source.page      year_loc
# 3     Bayern  Schwaben  Miller (2003)          14  1525Schwaben
# 4     Bayern  Schwaben  Miller (2003)          14  1525Schwaben
# 15    Bayern  Schwaben  Miller (2003)          38  1525Schwaben
# 18    Bayern  Schwaben  Miller (2003)          41  1525Schwaben

# %%
battles_clean = battles_clean.drop_duplicates(subset = ['year_loc'])
battles_clean.head()
# Out:
#            battle     month  year  decade  century            city  country  \
# 0           Trier    August  1522    1520     1500           Trier  Germany
# 1       Landstuhl     April  1523    1520     1500       Landstuhl  Germany
# 2  Donaueschingen  December  1524    1520     1500  Donaueschingen  Germany
# 3         Kempten     April  1525    1520     1500         Kempten  Germany
# 5         Wurzach     April  1525    1520     1500     Bad Wurzach  Germany
#
#                     war war.theater        lon        lat gadm.adm0  \
# 0       Knights' Revolt         NaN   6.637143  49.749992   Germany
# 1       Knights' Revolt         NaN   7.570905  49.414146   Germany
# 2  German Peasants' War         NaN   8.497946  47.952152   Germany
# 3  German Peasants' War         NaN  10.315784  47.728570   Germany
# 5  German Peasants' War         NaN   9.893829  47.908192   Germany
#
#            gadm.adm1          gadm.adm2            source source.page  \
# 0    Rheinland-Pfalz              Trier  Hitchcock (1958)           1
# 1    Rheinland-Pfalz  Rheinhessen-Pfalz  Hitchcock (1958)           1
# 2  Baden-Wurttemberg           Freiburg     Miller (2003)          17
# 3             Bayern           Schwaben     Miller (2003)          14
# 5  Baden-Wurttemberg           Tubingen     Miller (2003)          21
#
#                 year_loc
# 0              1522Trier
# 1  1523Rheinhessen-Pfalz
# 2           1524Freiburg
# 3           1525Schwaben
# 5           1525Tubingen

# %%
battles_merge = battles_clean[['year_loc', 'battle']]
battles_merge
# Out:
#                        year_loc                   battle
# 0                     1522Trier                    Trier
# 1         1523Rheinhessen-Pfalz                Landstuhl
# 2                  1524Freiburg           Donaueschingen
# 3                  1525Schwaben                  Kempten
# 5                  1525Tubingen                  Wurzach
# ..                          ...                      ...
# 418  1651Perthshire and Kinross                    Alyth
# 419                  1651Dundee                   Dundee
# 420              1651Manchester                    Wigan
# 421          1651Worcestershire                Worcester
# 423                1654Highland  Lochgarry (Dalnaspidal)
#
# [357 rows x 2 columns]

# %%
trials_clean.head()
# Out:
#      year  decade  century  tried  deaths city   gadm.adm2     gadm.adm1  \
# 230  1652    1650     1600      1     1.0  NaN      Geneve        Geneve
# 231  1782    1780     1700      1     1.0  NaN      Glarus        Glarus
# 258  1423    1420     1400      1     1.0  NaN      Sursee       Lucerne
# 303  1737    1730     1700      1     0.0  NaN    Willisau       Lucerne
# 390  1695    1690     1600      3     3.0  NaN  See-Gaster  Sankt Gallen
#
#        gadm.adm0  lon  lat record.source        year_loc
# 230  Switzerland  NaN  NaN  Bader (1945)      1652Geneve
# 231  Switzerland  NaN  NaN  Bader (1945)      1782Glarus
# 258  Switzerland  NaN  NaN  Bader (1945)      1423Sursee
# 303  Switzerland  NaN  NaN  Bader (1945)    1737Willisau
# 390  Switzerland  NaN  NaN  Bader (1945)  1695See-Gaster

# %%
trials_clean = trials_clean.drop(columns = ['city', 'lon', 'lat', 'deaths'])

# %%
trials_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9306 entries, 230 to 10902
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           9306 non-null   int32
#  1   decade         9306 non-null   int64
#  2   century        9306 non-null   int64
#  3   tried          9306 non-null   int64
#  4   gadm.adm2      9306 non-null   object
#  5   gadm.adm1      9306 non-null   object
#  6   gadm.adm0      9306 non-null   object
#  7   record.source  9306 non-null   object
#  8   year_loc       9306 non-null   object
# dtypes: int32(1), int64(3), object(5)
# memory usage: 690.7+ KB

# %%
df = pd.merge(left = trials_clean, right = battles_merge, on = 'year_loc', how = 'left')
df.head()
# Out:
#    year  decade  century  tried   gadm.adm2     gadm.adm1    gadm.adm0  \
# 0  1652    1650     1600      1      Geneve        Geneve  Switzerland
# 1  1782    1780     1700      1      Glarus        Glarus  Switzerland
# 2  1423    1420     1400      1      Sursee       Lucerne  Switzerland
# 3  1737    1730     1700      1    Willisau       Lucerne  Switzerland
# 4  1695    1690     1600      3  See-Gaster  Sankt Gallen  Switzerland
#
#   record.source        year_loc battle
# 0  Bader (1945)      1652Geneve    NaN
# 1  Bader (1945)      1782Glarus    NaN
# 2  Bader (1945)      1423Sursee    NaN
# 3  Bader (1945)    1737Willisau    NaN
# 4  Bader (1945)  1695See-Gaster    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9306 entries, 0 to 9305
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           9306 non-null   int32
#  1   decade         9306 non-null   int64
#  2   century        9306 non-null   int64
#  3   tried          9306 non-null   int64
#  4   gadm.adm2      9306 non-null   object
#  5   gadm.adm1      9306 non-null   object
#  6   gadm.adm0      9306 non-null   object
#  7   record.source  9306 non-null   object
#  8   year_loc       9306 non-null   object
#  9   battle         215 non-null    object
# dtypes: int32(1), int64(3), object(6)
# memory usage: 763.4+ KB

# %%
df['battle'] = np.where(df['battle'].isna(), 0, 1)
df['battle'].value_counts()
# Out:
# 0    9091
# 1     215
# Name: battle, dtype: int64

# %%
df.head()
# Out:
#    year  decade  century  tried   gadm.adm2     gadm.adm1    gadm.adm0  \
# 0  1652    1650     1600      1      Geneve        Geneve  Switzerland
# 1  1782    1780     1700      1      Glarus        Glarus  Switzerland
# 2  1423    1420     1400      1      Sursee       Lucerne  Switzerland
# 3  1737    1730     1700      1    Willisau       Lucerne  Switzerland
# 4  1695    1690     1600      3  See-Gaster  Sankt Gallen  Switzerland
#
#   record.source        year_loc  battle
# 0  Bader (1945)      1652Geneve       0
# 1  Bader (1945)      1782Glarus       0
# 2  Bader (1945)      1423Sursee       0
# 3  Bader (1945)    1737Willisau       0
# 4  Bader (1945)  1695See-Gaster       0

# %% [markdown]
# There are a lot of trials that have no battle associated. I think it will help to add a lag of 1-5 years because some of the effects may not be immediate.

# %%
battles_lag = battles_clean[['battle', 'year', 'gadm.adm2']]

# %%
lag_battles = {i: f'lag_{i}' for i in range(1, 6)}
lag_battles
# Out:
# {1: 'lag_1', 2: 'lag_2', 3: 'lag_3', 4: 'lag_4', 5: 'lag_5'}

# %%
for i, column_name in lag_battles.items():
    battles_lag[column_name] = (battles_lag['year'] + i).astype(str) + battles_lag['gadm.adm2']
    
    
battles_lag
# Out:
# <ipython-input-99-f4a43d818ac9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   battles_lag[column_name] = (battles_lag['year'] + i).astype(str) + battles_lag['gadm.adm2']
#                       battle  year               gadm.adm2  \
# 0                      Trier  1522                   Trier
# 1                  Landstuhl  1523       Rheinhessen-Pfalz
# 2             Donaueschingen  1524                Freiburg
# 3                    Kempten  1525                Schwaben
# 5                    Wurzach  1525                Tubingen
# ..                       ...   ...                     ...
# 418                    Alyth  1651  Perthshire and Kinross
# 419                   Dundee  1651                  Dundee
# 420                    Wigan  1651              Manchester
# 421                Worcester  1651          Worcestershire
# 423  Lochgarry (Dalnaspidal)  1654                Highland
#
#                           lag_1                       lag_2  \
# 0                     1523Trier                   1524Trier
# 1         1524Rheinhessen-Pfalz       1525Rheinhessen-Pfalz
# 2                  1525Freiburg                1526Freiburg
# 3                  1526Schwaben                1527Schwaben
# 5                  1526Tubingen                1527Tubingen
# ..                          ...                         ...
# 418  1652Perthshire and Kinross  1653Perthshire and Kinross
# 419                  1652Dundee                  1653Dundee
# 420              1652Manchester              1653Manchester
# 421          1652Worcestershire          1653Worcestershire
# 423                1655Highland                1656Highland
#
#                           lag_3                       lag_4  \
# 0                     1525Trier                   1526Trier
# 1         1526Rheinhessen-Pfalz       1527Rheinhessen-Pfalz
# 2                  1527Freiburg                1528Freiburg
# 3                  1528Schwaben                1529Schwaben
# 5                  1528Tubingen                1529Tubingen
# ..                          ...                         ...
# 418  1654Perthshire and Kinross  1655Perthshire and Kinross
# 419                  1654Dundee                  1655Dundee
# 420              1654Manchester              1655Manchester
# 421          1654Worcestershire          1655Worcestershire
# 423                1657Highland                1658Highland
#
#                           lag_5
# 0                     1527Trier
# 1         1528Rheinhessen-Pfalz
# 2                  1529Freiburg
# 3                  1530Schwaben
# 5                  1530Tubingen
# ..                          ...
# 418  1656Perthshire and Kinross
# 419                  1656Dundee
# 420              1656Manchester
# 421          1656Worcestershire
# 423                1659Highland
#
# [357 rows x 8 columns]

# %%
battles_lag = battles_lag.drop(columns = ['battle', 'year', 'gadm.adm2'])

# %%
columns = battles_lag.columns
columns
# Out:
# Index(['lag_1', 'lag_2', 'lag_3', 'lag_4', 'lag_5'], dtype='object')

# %%
df_trials = df.copy()

# %%
for column in columns:
    lag = battles_lag[[column]]
    temp_df = pd.merge(left = df_trials, right = lag, left_on = 'year_loc', right_on = column, how = 'left')
    temp_df[column] = np.where(temp_df[column].isna(), 0, 1)
    
    df_trials[column] = temp_df[column]

# %%
df_trials
# Out:
#       year  decade  century  tried       gadm.adm2     gadm.adm1    gadm.adm0  \
# 0     1652    1650     1600      1          Geneve        Geneve  Switzerland
# 1     1782    1780     1700      1          Glarus        Glarus  Switzerland
# 2     1423    1420     1400      1          Sursee       Lucerne  Switzerland
# 3     1737    1730     1700      1        Willisau       Lucerne  Switzerland
# 4     1695    1690     1600      3      See-Gaster  Sankt Gallen  Switzerland
# ...    ...     ...      ...    ...             ...           ...          ...
# 9301  1774    1770     1700      1  Hellevoetsluis  Zuid-Holland  Netherlands
# 9302  1777    1770     1700      1     Vlaardingen  Zuid-Holland  Netherlands
# 9303  1777    1770     1700      1       Maassluis  Zuid-Holland  Netherlands
# 9304  1779    1770     1700      1       Maassluis  Zuid-Holland  Netherlands
# 9305  1786    1780     1700      1       Maassluis  Zuid-Holland  Netherlands
#
#       record.source            year_loc  battle  lag_1  lag_2  lag_3  lag_4  \
# 0      Bader (1945)          1652Geneve       0      0      0      0      0
# 1      Bader (1945)          1782Glarus       0      0      0      0      0
# 2      Bader (1945)          1423Sursee       0      0      0      0      0
# 3      Bader (1945)        1737Willisau       0      0      0      0      0
# 4      Bader (1945)      1695See-Gaster       0      0      0      0      0
# ...             ...                 ...     ...    ...    ...    ...    ...
# 9301  Waardt (1991)  1774Hellevoetsluis       0      0      0      0      0
# 9302  Waardt (1991)     1777Vlaardingen       0      0      0      0      0
# 9303  Waardt (1991)       1777Maassluis       0      0      0      0      0
# 9304  Waardt (1991)       1779Maassluis       0      0      0      0      0
# 9305  Waardt (1991)       1786Maassluis       0      0      0      0      0
#
#       lag_5
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# ...     ...
# 9301      0
# 9302      0
# 9303      0
# 9304      0
# 9305      0
#
# [9306 rows x 15 columns]

# %%
df_trials['lag_1'].value_counts()
# Out:
# 0    9084
# 1     222
# Name: lag_1, dtype: int64

# %%
df_trials['lag_5'].value_counts()
# Out:
# 0    9205
# 1     101
# Name: lag_5, dtype: int64

# %%
df_trials.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9306 entries, 0 to 9305
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year           9306 non-null   int32
#  1   decade         9306 non-null   int64
#  2   century        9306 non-null   int64
#  3   tried          9306 non-null   int64
#  4   gadm.adm2      9306 non-null   object
#  5   gadm.adm1      9306 non-null   object
#  6   gadm.adm0      9306 non-null   object
#  7   record.source  9306 non-null   object
#  8   year_loc       9306 non-null   object
#  9   battle         9306 non-null   int32
#  10  lag_1          9306 non-null   int32
#  11  lag_2          9306 non-null   int32
#  12  lag_3          9306 non-null   int32
#  13  lag_4          9306 non-null   int32
#  14  lag_5          9306 non-null   int32
# dtypes: int32(7), int64(3), object(5)
# memory usage: 908.8+ KB

# %%
df_trials.drop(columns = ['year_loc'], inplace=True)

# %%
sns.pairplot(df_trials, corner = True);

# %%
X = df_trials.drop(columns = 'tried')
y = df_trials['tried']

# %%
X = pd.get_dummies(data = X, columns = ['gadm.adm2', 'gadm.adm1', 'gadm.adm0', 'record.source'], drop_first = True)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 8)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.score(X_test, y_test)
# Out:
# -1.15338320930475e+16
